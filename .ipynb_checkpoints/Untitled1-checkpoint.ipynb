# %%
pwd
# Out:
# '/home/mani/Desktop/DS_Training'

# %%
from data import fetch_data, feature_engineering

# %%
import pandas as pd
import numpy as np
import os

# %%
import reformat

# %%
root=os.getcwd()

# %%
x_train,y_train,x_test,y_test = fetch_data(root,remove_duplicates=True,binary=True)
# Out:
# Datasets loaded :)
# The dimensions of the training dataset is (145583, 41)
# The dimensions of test dataset is (311028, 41)
# The taken to load data is 5.06 secs

# %%
x_train
# Out:
#         duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp    http   SF        181       5450     0
# 1              0           tcp    http   SF        239        486     0
# 2              0           tcp    http   SF        235       1337     0
# 3              0           tcp    http   SF        219       1337     0
# 4              0           tcp    http   SF        217       2032     0
# 5              0           tcp    http   SF        217       2032     0
# 6              0           tcp    http   SF        212       1940     0
# 7              0           tcp    http   SF        159       4087     0
# 8              0           tcp    http   SF        210        151     0
# 9              0           tcp    http   SF        212        786     0
# 10             0           tcp    http   SF        210        624     0
# 11             0           tcp    http   SF        177       1985     0
# ...

# %%
x_train_json=x_train.to_json()

# %%
x_train.iloc[2:3,:].to_json()
# Out:
# '{"duration":{"1":0},"protocol_type":{"1":"tcp"},"service":{"1":"http"},"flag":{"1":"SF"},"src_bytes":{"1":239},"dst_bytes":{"1":486},"land":{"1":0},"wrong_fragment":{"1":0},"urgent":{"1":0},"hot":{"1":0},"num_failed_logins":{"1":0},"logged_in":{"1":1},"num_compromised":{"1":0},"root_shell":{"1":0},"su_attempted":{"1":0},"num_root":{"1":0},"num_file_creations":{"1":0},"num_shells":{"1":0},"num_access_files":{"1":0},"num_outbound_cmds":{"1":0},"is_host_login":{"1":0},"is_guest_login":{"1":0},"count":{"1":8},"srv_count":{"1":8},"serror_rate":{"1":0.0},"srv_serror_rate":{"1":0.0},"rerror_rate":{"1":0.0},"srv_rerror_rate":{"1":0.0},"same_srv_rate":{"1":1.0},"diff_srv_rate":{"1":0.0},"srv_diff_host_rate":{"1":0.0},"dst_host_count":{"1":19},"dst_host_srv_count":{"1":19},"dst_host_same_srv_rate":{"1":1.0},"dst_host_diff_srv_rate":{"1":0.0},"dst_host_same_src_port_rate":{"1":0.05},"dst_host_srv_diff_host_rate":{"1":0.0},"dst_host_serror_rate":{"1":0.0},"dst_host_srv_serror_rate":{"1":0.0},"d
# ...

# %%
x_train[x_train['service']!='http']
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 206            0           tcp      smtp   SF       3366        329     0
# 207            0           tcp      smtp   SF       1666        328     0
# 208            0           tcp      smtp   SF        751        279     0
# 209            0           tcp    finger   SF          9        140     0
# 210            0           tcp      smtp   SF        620        329     0
# 211            0           tcp      smtp   SF        805        327     0
# 212            0           tcp      smtp   SF        842        279     0
# 213            0           udp  domain_u   SF         33          0     0
# 214            0           udp  domain_u   SF         30          0     0
# 215            0           tcp      smtp   SF       1375        328     0
# 216            1           tcp      smtp   SF       1550        326     0
# 217            0           udp  domain_u   SF         30          0     0
# ...

# %%
len(list(set(x_train.service)))
# Out:
# 66
